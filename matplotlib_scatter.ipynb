# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exmples et 4 variables
# il y a 3 classes

# %%
n = x.shape[1]
plt.figure(figsize=(12, 8))
for i in range(n):
    plt.subplot(n//2, n//2, i+1)
    plt.scatter(x[:, 0], x[:, i], c=y)
    plt.xlabel('0')
    plt.ylabel(i)
    plt.colorbar(ticks=list(np.unique(y)), label="color")
plt.show()

# %%
import csv
with open('.\model\IDMTable.csv', 'rt') as f:
    csv_reader = list(csv.reader (f, delimiter=','))
    Chauffage = float(csv_reader[49][6])
print(Chauffage)
# Out:
# 669.29

# %%
liste=[0,1,2,3,4]
print(liste[:-1])
# Out:
# [0, 1, 2, 3]
